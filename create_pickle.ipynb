# %%
import pandas as pd
import glob
import os
os.chdir("/Users/claire/git/flatiron/capstone/listing_raw_data")

filenames = [i for i in glob.glob('*.csv')]

# %%
df = pd.concat((pd.read_csv(name).assign(city = name.split('_')[0], state = name.split('_')[1]) for name in filenames))

# %%
df.loc[df['city'] == 'Pacific-Grove'].sort_values(by = 'id',ascending=False).head(3)
# Out:
#                      id                                      listing_url  \
# 238  987019047100646374  https://www.airbnb.com/rooms/987019047100646374
# 237  979094077170965263  https://www.airbnb.com/rooms/979094077170965263
# 236  970638496026766579  https://www.airbnb.com/rooms/970638496026766579
#
#           scrape_id last_scraped       source  \
# 238  20230925193655   2023-09-25  city scrape
# 237  20230925193655   2023-09-25  city scrape
# 236  20230925193655   2023-09-25  city scrape
#
#                                                   name  \
# 238  Home in Pacific Grove · ★New · 3 bedrooms · 3 ...
# 237  Guesthouse in Pacific Grove · ★New · 1 bedroom...
# 236  Rental unit in Pacific Grove · ★New · 1 bedroo...
#
#                                            description  \
# 238  This renovated three-bedroom, two and one half...
# 237  Keep it simple at this peaceful and centrally-...
# 236  Take it easy at this unique and tranquil getaw...
#
# ...

# %% [markdown]
# ## Export to CSV:

# %%
df.to_csv('/Users/claire/git/flatiron/capstone/Data_Save_then_paste_Google_Colab/all_data_csv/all_airbnb_data.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Export to Pickle

# %%
# Most commonly used protocol is 0, and is backwards compatible w/ Python versions
path = '/Users/claire/git/flatiron/capstone/Data_Save_then_paste_Google_Colab/all_data_pickle/all_airbnb_data.pkl'
df.to_pickle(path, compression=None, protocol=0)

# %%
'/Users/claire/git/flatiron/capstone/Data_Save_then_paste_Google_Colab/all_data_csv/airbnb_data.csv'
